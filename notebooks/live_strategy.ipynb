# %%
import sys
import os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from src.utils.plots import run_live_plot
from src.signal.signals_live import simple_signal

# %%
strat = simple_signal
run_live_plot(ticker="BTC-USD", interval=10, duration_minutes=10, signal_func=strat)
